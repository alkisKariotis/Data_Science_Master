# %% [markdown]
# # Midterm ITC 6001 – INTRODUCTION TO BIG DATA

# %% [markdown]
# ## Q1: Python: Pandas Data frames 50%
#
# Q1 work to be done

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Print the min, max, average & the std for the Item_Weight

# %%
from detect_delimiter import detect

filename = "mall.csv"
with open(filename) as f:
    firstline = f.readline()
    delimiter = detect(firstline)

records = pd.read_csv(filename, sep = delimiter)

# %%
#This is the delimiter
delimiter
# Out:
# ','

# %%
df = pd.read_csv('mall.csv',delimiter=',')
df
#df['Item_Weight'].describe()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Printing the max
df['Item_Weight'].max()
# Out:
# 21.35

# %%
#Printing the min
df['Item_Weight'].min()
# Out:
# 4.555

# %%
#Printing the std
df['Item_Weight'].std()
# Out:
# 4.643456499186395

# %%
#or printing them all together
max = df['Item_Weight'].max()
min = df['Item_Weight'].min()
std = df['Item_Weight'].std()
result = (max, min, std)
print(result)
# Out:
# (21.35, 4.555, 4.643456499186395)

# %% [markdown]
# ### 2. Count the number of items (based on Item_Identifier column per outlet type).

# %%
question2 = df.groupby('Outlet_Type')['Item_Identifier'].nunique()
print("Number of items", question2)
# Out:
# Number of items Outlet_Type
# Grocery Store         901
# Supermarket Type1    1550
# Supermarket Type2     928
# Supermarket Type3     935
# Name: Item_Identifier, dtype: int64

# %%
question2.reset_index()
# Out:
#          Outlet_Type  Item_Identifier
# 0      Grocery Store              901
# 1  Supermarket Type1             1550
# 2  Supermarket Type2              928
# 3  Supermarket Type3              935

# %% [markdown]
# ### 3. Print the unique item names (use feature 'Item_Type' )

# %%
question3 = df['Item_Type'].unique()
print("Unique item names:", question3)
# Out:
# Unique item names: ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']

# %% [markdown]
# ### 4. Print the unique Item Identifiers

# %%
question4 = df['Item_Identifier'].unique()
print("Unique item identifiers: \n", question4)
# Out:
# Unique item identifiers:
#  ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']

# %%
len(question4)
# Out:
# 1559

# %% [markdown]
# ### 5. Print the total number of items sold per Outlet_Identifier

# %%
question5 = df.groupby('Outlet_Identifier')['Item_Identifier'].count()
#The column Item_identifier represents the count
question5.reset_index()
# Out:
#   Outlet_Identifier  Item_Identifier
# 0            OUT010              555
# 1            OUT013              932
# 2            OUT017              926
# 3            OUT018              928
# 4            OUT019              528
# 5            OUT027              935
# 6            OUT035              930
# 7            OUT045              929
# 8            OUT046              930
# 9            OUT049              930

# %% [markdown]
# ### 6. Print the item identifier and weight for items heavier than 21.3

# %%
question6 = df[df['Item_Weight'] > 21.3][['Item_Identifier', 'Item_Weight']]
question6
# Out:
#      Item_Identifier  Item_Weight
# 43             FDC02        21.35
# 483            FDC02        21.35
# 2368           FDC02        21.35
# 2802           FDC02        21.35
# 4257           FDR07        21.35
# 4468           FDC02        21.35
# 6389           FDR07        21.35

# %% [markdown]
# ### 7. Compute the following pivot table that counts the number of items per outlet_size, and per Tier. (Hint aggregation function 'count'.).

# %%
question7 = pd.pivot_table(df, values='Item_Identifier', index=['Outlet_Size'], 
                         columns=['Outlet_Location_Type'], aggfunc='count')
#print("Q1-7 Result:", result7)
question7
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3
# Outlet_Size
# High                     NaN     NaN   932.0
# Medium                 930.0     NaN  1863.0
# Small                 1458.0   930.0     NaN

# %% [markdown]
# ### 8. Print for Outlet_Establishment_Year (in rows), and per Outlet_size (in columns). You should have the total number of items sold in each cell.

# %%
question8 = pd.pivot_table(df, values='Item_Identifier', index=['Outlet_Establishment_Year'],columns=['Outlet_Size'], aggfunc='count')
question8
# Out:
# Outlet_Size                 High  Medium  Small
# Outlet_Establishment_Year
# 1985                         NaN   935.0  528.0
# 1987                       932.0     NaN    NaN
# 1997                         NaN     NaN  930.0
# 1999                         NaN   930.0    NaN
# 2004                         NaN     NaN  930.0
# 2009                         NaN   928.0    NaN

# %% [markdown]
# ### 9. Print the rows where the Item_type is meat or Baking goods

# %%
question9 = df[df['Item_Type'].isin(['Meat', 'Baking Goods'])]
question9
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2              FDN15       17.500          Low Fat         0.016760
# 5              FDP36       10.395          Regular         0.000000
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 41             FDK43        9.800          Low Fat         0.026818
# ...              ...          ...              ...              ...
# 8470           FDW27        5.860          Regular         0.151088
# 8491           FDO03       10.395          Regular         0.037033
# 8513           FDH31       12.000          Regular         0.020407
# 8515           FDH24       20.700          Low Fat         0.021518
# 8519           FDS36        8.380          Regular         0.046982
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2             Meat  141.6180            OUT049                       1999
# ...

# %%
#Or another way with the OR operator
df[(df['Item_Type']=='Meat') | (df['Item_Type']=='Baking Goods')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2              FDN15       17.500          Low Fat         0.016760
# 5              FDP36       10.395          Regular         0.000000
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 41             FDK43        9.800          Low Fat         0.026818
# ...              ...          ...              ...              ...
# 8470           FDW27        5.860          Regular         0.151088
# 8491           FDO03       10.395          Regular         0.037033
# 8513           FDH31       12.000          Regular         0.020407
# 8515           FDH24       20.700          Low Fat         0.021518
# 8519           FDS36        8.380          Regular         0.046982
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2             Meat  141.6180            OUT049                       1999
# ...

# %% [markdown]
# ### 10. Remove the columns that are marked with outlet_type, and item_identifier

# %%
#Creating a copy so we dont loose the original dataset
df2=df.copy()

# %%
df2.drop(columns=['Item_Identifier', 'Outlet_Type',], inplace=True)
df2
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...
